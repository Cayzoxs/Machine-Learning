# %% [markdown]
# <a href="https://colab.research.google.com/github/Cayzoxs/Machine-Learning/blob/week-3-naive-bayes/03_Model_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Persiapan Data Latih dan Uji

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)

X_train, X_test, y_train, y_test = train_test_split(df.drop('Outcome', axis=1), df['Outcome'], test_size=0.2, random_state=42)

# %% [markdown]
# # 2. Pelatihan dan Evaluasi Naive Bayes

# %%
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

y_pred = nb_model.predict(X_test)
print(f"Akurasi Model Naive Bayes: {accuracy_score(y_test, y_pred) * 100:.2f}%")
# Out:
# Akurasi Model Naive Bayes: 76.62%
