# %% [markdown]
# <a href="https://colab.research.google.com/github/Cayzoxs/Machine-Learning/blob/week-1-eda/01_Eksplorasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Mengimpor Library dan Memuat Dataset

# %%
# 1. Mengimpor library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Memuat dataset dari internet
url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)

# 3. Melihat 5 baris pertama data
print("--- 5 Baris Pertama Dataset ---")
display(df.head())

# 4. Mengecek informasi kolom dan nilai kosong
print("\n--- Informasi Dataset ---")
print(df.info())
print("\nJumlah Data Kosong:")
print(df.isnull().sum())

# 5. Visualisasi perbandingan target (0 = Tidak Diabetes, 1 = Diabetes)
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Outcome', palette='Set2')
plt.title("Perbandingan Pasien Diabetes (1) dan Tidak Diabetes (0)")
plt.show()
# Out:
# --- 5 Baris Pertama Dataset ---
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# --- Informasi Dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
# ...

# %% [markdown]
# # 2. Inspeksi Karakteristik Data

# %%
print("--- 5 Baris Pertama Dataset ---")
display(df.head())

print("\n--- Informasi Dataset ---")
print(df.info())

print("\nJumlah Data Kosong:")
print(df.isnull().sum())
# Out:
# --- 5 Baris Pertama Dataset ---
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# --- Informasi Dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
# ...

# %% [markdown]
# # 3. Visualisasi Distribusi Target (EDA)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Outcome', palette='Set2')
plt.title("Perbandingan Pasien Diabetes (1) dan Tidak Diabetes (0)")
plt.show()
# Out:
# /tmp/ipykernel_2366/33475840.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Outcome', palette='Set2')
